# %% [markdown]
# Run the command below in a PyCharm WSL window to access the Python virtual environment:
#
# ```shell
#  source /home/penguini/.virtualenvs/DrChanWorkPlayground/bin/activate
# ```

# %%
import tensorflow as tf

# List available physical devices
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))

# If GPUs are found, check if TensorFlow is built with CUDA/ROCm support
if len(physical_devices) > 0:
    print("TensorFlow is built with GPU support:", tf.test.is_built_with_cuda())
# Out:
# Num GPUs Available:  1
# TensorFlow is built with GPU support: True

# %%
import numpy as np
import keras
from keras import layers
from tensorflow.keras.datasets import fashion_mnist

(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
inputs = keras.Input(shape=(28,28))
flatten = layers.Flatten()(inputs)
hidden = layers.Dense(64, activation='relu')(flatten)
output = layers.Dense(10, activation='softmax')(hidden)

model = keras.Model(inputs=inputs, outputs=output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=256, epochs=20, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.6601 - loss: 6.3581 - val_accuracy: 0.6767 - val_loss: 1.4215
# Epoch 2/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7131 - loss: 1.1300 - val_accuracy: 0.7100 - val_loss: 1.0650
# Epoch 3/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7385 - loss: 0.9139 - val_accuracy: 0.7296 - val_loss: 0.9295
# Epoch 4/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7432 - loss: 0.7761 - val_accuracy: 0.7228 - val_loss: 0.8095
# Epoch 5/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7437 - loss: 0.6905 - val_accuracy: 0.7302 - val_loss: 0.7486
# Epoch 6/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7482 - loss: 0.6480 - val_accuracy: 0.7272 - val_loss: 0.7254
# Epoch 7/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7548 - loss: 0.6163 - val_accuracy: 0.7551 - val_loss: 0.6902
# Epoch 8/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7589 - loss: 0.6013 - val_accuracy: 0.7420 - val_loss: 0.6737
# Epoch 9/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7657 - loss: 0.5795 - val_accuracy: 0.7476 - val_loss: 0.6628
# Epoch 10/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7716 - loss: 0.5639 - val_accuracy: 0.7567 - val_loss: 0.6534
# Epoch 11/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7771 - loss: 0.5508 - val_accuracy: 0.7470 - val_loss: 0.6497
# Epoch 12/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7846 - loss: 0.5395 - val_accuracy: 0.7653 - val_loss: 0.6220
# Epoch 13/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7908 - loss: 0.5275 - val_accuracy: 0.7801 - val_loss: 0.6055
# Epoch 14/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7947 - loss: 0.5207 - val_accuracy: 0.7855 - val_loss: 0.5980
# Epoch 15/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7979 - loss: 0.5118 - val_accuracy: 0.7889 - val_loss: 0.5866
# Epoch 16/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8038 - loss: 0.5005 - val_accuracy: 0.7860 - val_loss: 0.5949
# Epoch 17/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8077 - loss: 0.4935 - val_accuracy: 0.7876 - val_loss: 0.5943
# Epoch 18/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8126 - loss: 0.4861 - val_accuracy: 0.8066 - val_loss: 0.5609
# Epoch 19/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8222 - loss: 0.4758 - val_accuracy: 0.8155 - val_loss: 0.5529
# Epoch 20/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8308 - loss: 0.4629 - val_accuracy: 0.8094 - val_loss: 0.5523

# %%
test_scores = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8094 - loss: 0.5523

# %%
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# Test loss: 0.5522586703300476
# Test accuracy: 0.8094000220298767

# %%
print(history)
# Out:
# <keras.src.callbacks.history.History object at 0x7eaeb5dece20>

# %%
import matplotlib.pyplot as plt

labels = [
    "T-shirt/top",
    "Trouser",
    "Pullover",
    "Dress",
    "Coat",
    "Sandal",
    "Shirt",
    "Sneaker",
    "Bag",
    "Ankle boot"
]

data_index = 8


plt.imshow(x_test[data_index], cmap=plt.get_cmap('gray'))
print(labels[np.argmax(model.predict(np.reshape(x_test[data_index], (1, 28, 28))))])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Sandal

# %%
import tensorflow as tf

# List available physical devices
physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))

# If GPUs are found, check if TensorFlow is built with CUDA/ROCm support
if len(physical_devices) > 0:
    print("TensorFlow is built with GPU support:", tf.test.is_built_with_cuda())
# Out:
# Num GPUs Available:  1
# TensorFlow is built with GPU support: True

# %%
import numpy as np
import keras
from keras import layers
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
inputs = keras.Input(shape=(28,28))
flatten = layers.Flatten()(inputs)
hidden = layers.Dense(64, activation='relu')(flatten)
output = layers.Dense(10, activation='softmax')(hidden)

model = keras.Model(inputs=inputs, outputs=output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=256, epochs=20, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8047 - loss: 8.5897 - val_accuracy: 0.8727 - val_loss: 2.2964
# Epoch 2/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8748 - loss: 1.4018 - val_accuracy: 0.8785 - val_loss: 0.8881
# Epoch 3/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8828 - loss: 0.6722 - val_accuracy: 0.8833 - val_loss: 0.6637
# Epoch 4/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9028 - loss: 0.4801 - val_accuracy: 0.9081 - val_loss: 0.5387
# Epoch 5/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9151 - loss: 0.3829 - val_accuracy: 0.9137 - val_loss: 0.4882
# Epoch 6/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9245 - loss: 0.3192 - val_accuracy: 0.9196 - val_loss: 0.4580
# Epoch 7/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9317 - loss: 0.2747 - val_accuracy: 0.9219 - val_loss: 0.4143
# Epoch 8/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9360 - loss: 0.2421 - val_accuracy: 0.9236 - val_loss: 0.3966
# Epoch 9/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9416 - loss: 0.2165 - val_accuracy: 0.9325 - val_loss: 0.3635
# Epoch 10/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9478 - loss: 0.1931 - val_accuracy: 0.9325 - val_loss: 0.3423
# Epoch 11/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9507 - loss: 0.1753 - val_accuracy: 0.9324 - val_loss: 0.3353
# Epoch 12/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9530 - loss: 0.1671 - val_accuracy: 0.9385 - val_loss: 0.3217
# Epoch 13/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9563 - loss: 0.1534 - val_accuracy: 0.9378 - val_loss: 0.3389
# Epoch 14/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9590 - loss: 0.1428 - val_accuracy: 0.9365 - val_loss: 0.3447
# Epoch 15/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9604 - loss: 0.1369 - val_accuracy: 0.9381 - val_loss: 0.3107
# Epoch 16/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9607 - loss: 0.1337 - val_accuracy: 0.9438 - val_loss: 0.3084
# Epoch 17/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9633 - loss: 0.1265 - val_accuracy: 0.9441 - val_loss: 0.3284
# Epoch 18/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9646 - loss: 0.1195 - val_accuracy: 0.9452 - val_loss: 0.2946
# Epoch 19/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9653 - loss: 0.1167 - val_accuracy: 0.9458 - val_loss: 0.3007
# Epoch 20/20
# 235/235 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9663 - loss: 0.1128 - val_accuracy: 0.9439 - val_loss: 0.3169

# %%
test_scores = model.evaluate(x_test, y_test, verbose=1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9439 - loss: 0.3169

# %%
print("Test loss:", test_scores[0])
print("Test accuracy:", test_scores[1])
# Out:
# Test loss: 0.31694167852401733
# Test accuracy: 0.9438999891281128

# %%
print(history)
# Out:
# <keras.src.callbacks.history.History object at 0x7eaeb436bac0>

# %%
import matplotlib.pyplot as plt

data_index = 12


plt.imshow(x_test[data_index], cmap=plt.get_cmap('gray'))
print(np.argmax(model.predict(np.reshape(x_test[data_index], (1, 28, 28)))))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 9
