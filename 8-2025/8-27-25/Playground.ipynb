# %% [markdown]
# # TPR

# %%
from imbal.metrics import TPR

test_metric = TPR()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# tpr
# <tf.Tensor: shape=(), dtype=float64, numpy=1.0>

# %% [markdown]
# # FPR

# %%
from imbal.metrics import FPR

test_metric = FPR()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# fpr
# <tf.Tensor: shape=(), dtype=float64, numpy=0.5>

# %% [markdown]
# # TNR

# %%
from imbal.metrics import TNR

test_metric = TNR()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# tnr
# <tf.Tensor: shape=(), dtype=float64, numpy=0.5>

# %% [markdown]
# # Precision

# %%
from imbal.metrics import Precision

test_metric = Precision()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# precision
# <tf.Tensor: shape=(), dtype=float64, numpy=0.6666666666666666>

# %% [markdown]
# # Expected TP

# %%
from imbal.metrics import ExpectedTP

test_metric = ExpectedTP()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# expected_tp
# <tf.Tensor: shape=(), dtype=float64, numpy=1.5>

# %% [markdown]
# # Expected TN

# %%
from imbal.metrics import ExpectedTN

test_metric = ExpectedTN()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# expected_tn
# <tf.Tensor: shape=(), dtype=float64, numpy=0.5>

# %% [markdown]
# # Expected Correct

# %%
from imbal.metrics import ExpectedCorrect

test_metric = ExpectedCorrect()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# expected_correct
# <tf.Tensor: shape=(), dtype=float64, numpy=2.0>

# %% [markdown]
# # TSS

# %%
from imbal.metrics import TSS

test_metric = TSS()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# tss
# <tf.Tensor: shape=(), dtype=float64, numpy=0.5>

# %% [markdown]
# # HSS

# %%
from imbal.metrics import HSS

test_metric = HSS()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# hss
# <tf.Tensor: shape=(), dtype=float64, numpy=0.5>

# %% [markdown]
# # Gilbert Skill Score (GS)

# %%
from imbal.metrics import GS

test_metric = GS()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# gs
# <tf.Tensor: shape=(), dtype=float64, numpy=0.3333333333333333>

# %% [markdown]
# # Critical Success Index (CSI)

# %%
from imbal.metrics import CSI

test_metric = CSI()
print(test_metric.name)
test_metric.update_state([1, 1, 0, 0], [1, 1, 1, 0])
test_metric.result()
# Out:
# csi
# <tf.Tensor: shape=(), dtype=float64, numpy=0.6666666666666666>
